# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf

# %%
df=pd.read_csv("D:/Semester5Project/og.csv",low_memory=False)

# %%
df.head()
# Out:
#         srcip  sport          dstip dsport proto state       dur  sbytes  \
# 0  59.166.0.0  33661  149.171.126.9   1024   udp   CON  0.036133     528
# 1  59.166.0.6   1464  149.171.126.7     53   udp   CON  0.001119     146
# 2  59.166.0.5   3593  149.171.126.5     53   udp   CON  0.001209     132
# 3  59.166.0.3  49664  149.171.126.0     53   udp   CON  0.001169     146
# 4  59.166.0.0  32119  149.171.126.9    111   udp   CON  0.078339     568
#
#    dbytes  sttl  ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst ct_dst_ltm  \
# 0     304    31  ...           0           2           4          2
# 1     178    31  ...           0          12           8          1
# 2     164    31  ...           0           6           9          1
# 3     178    31  ...           0           7           9          1
# 4     312    31  ...           0           2           4          2
#
#    ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# 0            3                 1                 1               2
# 1            2                 2                 1               1
# 2            1                 1                 1               1
# 3            1                 1                 1               1
# 4            3                 1                 1               2
#
#    attack_cat  Label
# 0         NaN      0
# 1         NaN      0
# 2         NaN      0
# 3         NaN      0
# 4         NaN      0
#
# [5 rows x 49 columns]

# %%
del df
import gc
gc.collect()
gc.collect()
gc.collect()
gc.collect()
# Out:
# 0

# %%
df.drop(index=df[df.duplicated()].index,inplace=True)

# %%
for i in df.select_dtypes(exclude=np.number).columns:
    print(i,df[i].str.isspace().any())
# Out:
# srcip False
# sport False
# dstip False
# dsport False
# proto False
# state False
# service False
# ct_ftp_cmd True
# attack_cat False

# %%
df['service'].value_counts()
# Out:
# -           1169177
# dns          386754
# http         203531
# ftp-data     124849
# smtp          81132
# ssh           46981
# ftp           45074
# pop3           1490
# ssl             142
# snmp            113
# dhcp            102
# radius           37
# irc              31
# Name: service, dtype: int64

# %%
indexes=[]
for i,j in df['ct_ftp_cmd'].str.isspace().items():
    if(j==True):
        indexes.append(i)
df['ct_ftp_cmd'].loc[indexes]=np.nan
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df['ct_ftp_cmd'].value_counts(dropna=False)
# Out:
# NaN    1014165
# 0      1005477
# 1        38853
# 2          263
# 4          250
# 3          206
# 5          105
# 6           91
# 8            3
# Name: ct_ftp_cmd, dtype: int64

# %% [markdown]
# Dropping the IP Addresses as they are not useful (and attack_cat)

# %%
df.drop(columns=['srcip','dstip','attack_cat'],inplace=True)

# %%
df=df.replace('-',np.nan)

# %%
df['sport']=df['sport'].apply(lambda x: '12' if x=='0x000c' else x)
df['sport']=df['sport'].apply(lambda x: '11' if x=='0x000b' else x)
df['sport']=df['sport'].astype('float64')

# %%
df['dsport']=df['dsport'].apply(lambda x: '52233' if x=='0xcc09' else x)
df['dsport']=df['dsport'].apply(lambda x: '49320' if x=='0xc0a8' else x)
df['dsport']=df['dsport'].apply(lambda x: np.nan if x=='0x20205321' else x)
df['dsport']=df['dsport'].astype('float64')

# %%
df['ct_ftp_cmd']=df['ct_ftp_cmd'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-a10ed3518ebd> in <module>
# ----> 1 df['ct_ftp_cmd']=df['ct_ftp_cmd'].astype(int)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5535         else:
#    5536             # else, only a single dtype is given
# -> 5537             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5538             return self._constructor(new_data).__finalize__(self, method="astype")
#    5539
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
#     597     def convert(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     587             vals1d = values.ravel()
#     588             try:
# --> 589                 values = astype_nansafe(vals1d, dtype, copy=True)
#     590             except (ValueError, TypeError):
#     591                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     964         # work around NumPy brokenness, #1987
#     965         if np.issubdtype(dtype.type, np.integer):
# --> 966             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     967
#     968         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: cannot convert float NaN to integer

# %%
df.select_dtypes(exclude=np.number)
# Out:
#         proto state   service ct_ftp_cmd
# 0         udp   CON       NaN          0
# 1         udp   CON       dns          0
# 2         udp   CON       dns          0
# 3         udp   CON       dns          0
# 4         udp   CON       NaN          0
# ...       ...   ...       ...        ...
# 2540035   tcp   CON      http        NaN
# 2540037   tcp   CON       NaN        NaN
# 2540038   tcp   FIN  ftp-data        NaN
# 2540041   tcp   CON      http        NaN
# 2540042   tcp   CON      pop3        NaN
#
# [2059413 rows x 4 columns]

# %%
df['ct_ftp_cmd']=df['ct_ftp_cmd'].astype(float)

# %%
dummies=pd.get_dummies(df[['proto','state','service']])

# %%
df.drop(columns=['proto','state','service'],inplace=True)

# %%
df=pd.concat([df,dummies],axis=1)

# %%
df.shape
# Out:
# (2059413, 46)

# %%
sum(df['service'].value_counts(dropna=False).iloc[1:])
# Out:
# 890236

# %%
nans=list(df.isnull().any()[df.isnull().any()==True].index)
for i in nans:
    print(i,(df[i].value_counts(dropna=False).iloc[0]/(df[i].value_counts(dropna=False).iloc[0]+sum(df[i].value_counts(dropna=False).iloc[1:])))*100)
# Out:
# service 56.77234241019165
# ct_flw_http_mthd 45.33345181369643
# is_ftp_login 49.24534321187639
# ct_ftp_cmd 49.24534321187639

# %%
nans[3:]
# Out:
# ['ct_ftp_cmd']

# %%
df[nans[2:]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2059413 entries, 0 to 2540042
# Data columns (total 4 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   service           int32
#  1   ct_flw_http_mthd  float64
#  2   is_ftp_login      float64
#  3   ct_ftp_cmd        float64
# dtypes: float64(3), int32(1)
# memory usage: 150.7 MB

# %%
df

# %%
from sklearn.impute import KNNImputer,SimpleImputer
imp=KNNImputer(n_neighbors=3)
imp1=SimpleImputer()
imp2=SimpleImputer(missing_values=9)
imp3=KNNImputer(missing_values=9)
df['sport']=imp.fit_transform(np.array(df['sport']).reshape(-1,1))
print('1/4 done')
df['dsport']=imp1.fit_transform(np.array(df['dsport']).reshape(-1,1))
print('2/4 done')
df[nans[1]]=imp1.fit_transform(np.array(df[nans[1]]).reshape(-1,1))
print('1 done')
df[nans[2]]=imp1.fit_transform(np.array(df[nans[2]]).reshape(-1,1))
print('2 done')
df[nans[3]]=imp1.fit_transform(np.array(df[nans[3]]).reshape(-1,1))
print('3 done')
df['service']=imp2.fit_transform(np.array(df['service']).reshape(-1,1))
print('All done')
# Out:
# 1/4 done
# 2/4 done
# 1 done
# 2 done
# 3 done
# All done

# %%
df[['proto','state','service']]
# Out:
#         proto state   service
# 0         udp   CON       NaN
# 1         udp   CON       dns
# 2         udp   CON       dns
# 3         udp   CON       dns
# 4         udp   CON       NaN
# ...       ...   ...       ...
# 2540035   tcp   CON      http
# 2540037   tcp   CON       NaN
# 2540038   tcp   FIN  ftp-data
# 2540041   tcp   CON      http
# 2540042   tcp   CON      pop3
#
# [2059413 rows x 3 columns]

# %%
df.isnull().any()[df.isnull().any()==True]
# Out:
# ct_flw_http_mthd    True
# is_ftp_login        True
# ct_ftp_cmd          True
# dtype: bool

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()
for i in ['proto','state','service']:
    df[i]=enc.fit_transform(df[i].astype(str))
    print(i)
df[['proto','state','service']]
# Out:
# proto
# state
# service
#          proto  state  service
# 0          120      2        6
# 1          120      2        1
# 2          120      2        1
# 3          120      2        1
# 4          120      2        6
# ...        ...    ...      ...
# 2540035    114      2        4
# 2540037    114      2        6
# 2540038    114      5        3
# 2540041    114      2        4
# 2540042    114      2        7
#
# [2059413 rows x 3 columns]

# %%
df['service'].value_counts(dropna=False)
# Out:
# 9     1169177
# 1      386754
# 7      203531
# 6      124849
# 12      81132
# 3       46981
# 5       45074
# 10       1490
# 4         142
# 2         113
# 0         102
# 11         37
# 8          31
# Name: service, dtype: int64

# %%
df['service'].unique()
# Out:
# array([ 6,  1,  4,  9,  3,  2, 11,  7, 10, 12,  5,  8,  0])

# %%
del [X_train,X_test,y_train,y_test]
gc.collect()
gc.collect()
gc.collect()
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-b028539914e9> in <module>
# ----> 1 del [X_train,X_test,y_train,y_test]
#       2 gc.collect()
#       3 gc.collect()
#       4 gc.collect()
#       5 gc.collect()
#
# NameError: name 'X_train' is not defined

# %%
dfcorr=df.corr()

# %%
dfcorr.shape
# Out:
# (45, 45)

# %%
df['Duration']=df['Ltime']-df['Stime']
df.drop(columns=['Ltime','Stime'],inplace=True)

# %%
dfcorr.drop(index='Label',inplace=True)

# %%
plt.style.use('seaborn')
fig, axes = plt.subplots(1, 2, figsize=(18, 10))
sns.heatmap(pd.DataFrame(dfcorr['Label'][0:22]),annot=True,ax=axes[0])
sns.heatmap(pd.DataFrame(dfcorr['Label'][22:]),annot=True,ax=axes[1])
# Out:
# <AxesSubplot:>

# %%
dfvar=df.var()

# %%
plt.style.use('seaborn')
fig, axes = plt.subplots(3, 3, figsize=(23, 38))
sns.heatmap(pd.DataFrame(dfvar[0:23]),annot=True,ax=axes[0][0])
sns.heatmap(pd.DataFrame(dfvar[23:46]),annot=True,ax=axes[0][1])
sns.heatmap(pd.DataFrame(dfvar[46:69]),annot=True,ax=axes[0][2])
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.8, hspace=None)
sns.heatmap(pd.DataFrame(dfvar[69:92]),annot=True,ax=axes[1][0])
sns.heatmap(pd.DataFrame(dfvar[92:115]),annot=True,ax=axes[1][1])
sns.heatmap(pd.DataFrame(dfvar[115:138]),annot=True,ax=axes[1][2])
sns.heatmap(pd.DataFrame(dfvar[138:161]),annot=True,ax=axes[2][0])
sns.heatmap(pd.DataFrame(dfvar[161:184]),annot=True,ax=axes[2][1])
sns.heatmap(pd.DataFrame(dfvar[184:]),annot=True,ax=axes[2][2])
fig.savefig('variances.jpg')

# %%
X_train.columns
# Out:
# Index(['sport', 'dsport', 'proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl',
#        'dttl', 'sloss', 'dloss', 'service', 'Sload', 'Dload', 'Spkts', 'Dpkts',
#        'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth',
#        'res_bdy_len', 'Sjit', 'Djit', 'Stime', 'Ltime', 'Sintpkt', 'Dintpkt',
#        'tcprtt', 'synack', 'ackdat', 'is_sm_ips_ports', 'ct_state_ttl',
#        'ct_flw_http_mthd', 'is_ftp_login', 'ct_ftp_cmd', 'ct_srv_src',
#        'ct_srv_dst', 'ct_dst_ltm', 'ct_src_ ltm', 'ct_src_dport_ltm',
#        'ct_dst_sport_ltm', 'ct_dst_src_ltm'],
#       dtype='object')

# %%
X_train
# Out:
#            sport   dsport  proto  state        dur  sbytes  dbytes  sttl  \
# 501146    9746.0     80.0    114      5   1.072976    1684   10168    31
# 214980   52147.0  29416.0    114      5   0.005162    4256    2456    31
# 982590    1220.0  31271.0    114      5   0.072939    2750   25684    31
# 843180   20074.0     53.0    120      2   0.001094     146     178    31
# 2070047  48454.0     53.0    120      2   0.001009     146     178    31
# ...          ...      ...    ...    ...        ...     ...     ...   ...
# 1026673  28729.0  21543.0    114      5   0.017871    2646   24666    31
# 126572   50009.0    111.0    120      2   0.004708     568     320    31
# 1728872  54957.0  22736.0    120      2   0.001738     520     304    31
# 320787   53322.0     53.0    120      2   0.001020     146     178    31
# 2505634  18870.0   2745.0    114      9  10.100009     360       0   254
#
#          dttl  sloss  ...  is_ftp_login  ct_ftp_cmd  ct_srv_src  ct_srv_dst  \
# 501146     29      3  ...      0.000000     0.00000           1           3
# 214980     29      7  ...      0.000000     0.00000           8           6
# 982590     29      7  ...      0.000000     0.00000          14          11
# 843180     29      0  ...      0.000000     0.00000           3           4
# 2070047    29      0  ...      0.038237     0.04027           2           1
# ...       ...    ...  ...           ...         ...         ...         ...
# 1026673    29      7  ...      0.000000     0.00000           2           4
# 126572     29      0  ...      0.000000     0.00000           6           5
# 1728872    29      0  ...      0.038237     0.04027           9           6
# 320787     29      0  ...      0.000000     0.00000           3           5
# 2505634     0      7  ...      0.038237     0.04027          28          27
#
#          ct_dst_ltm  ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  \
# 501146            3            5                 1                 1
# 214980            5            4                 1                 1
# 982590            3            4                 1                 1
# 843180            3            8                 2                 1
# 2070047           2            3                 1                 1
# ...             ...          ...               ...               ...
# 1026673           2            2                 1                 1
# 126572            6            5                 2                 1
# 1728872           7            3                 1                 1
# 320787            5            3                 2                 1
# 2505634          10           11                 2                 2
#
#          ct_dst_src_ltm  duration
# 501146                3         1
# 214980                3         0
# 982590                3         0
# 843180                2         0
# 2070047               1         0
# ...                 ...       ...
# 1026673               1         0
# 126572                3         0
# 1728872               3         0
# 320787                1         0
# 2505634              27        10
#
# [1441589 rows x 46 columns]

# %%
# Out:
# 501146     1421946216
# 214980     1421935624
# 982590     1421968291
# 843180     1421962298
# 2070047    1424248814
#               ...
# 1026673    1421970187
# 126572     1421932140
# 1728872    1424239453
# 320787     1421940564
# 2505634    1424261173
# Name: Ltime, Length: 1441589, dtype: int64

# %%
import dtale
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://NierHominum:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from xgboost import XGBClassifier
import xgboost as xgb
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import gc
'''
X=df.drop("Label",axis=1)
y=df['Label']
del [df]
gc.collect()
gc.collect()
gc.collect()
print('X,y defined')
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
del [X,y]
gc.collect()
gc.collect()
gc.collect()
print('Split Created')
'''
model=XGBClassifier(predictor='gpu_predictor',
                    objective='multi:softmax',
                    n_estimators=4,
                    scale_pos_weight=20,
                    max_depth=9,
                    num_class=2,
                    verbosity=3)
print('model defined')
model.fit(X_train,y_train)
print('model fitted')
print(accuracy_score(y_train,model.predict(X_train)))
print(accuracy_score(y_test,model.predict(X_test)))
# Out:
# model defined
# [15:56:48] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { scale_pos_weight } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:56:49] DEBUG: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\gbm\gbtree.cc:147: Using tree method: 2
# [15:56:54] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\tree\updater_prune.cc:101: tree pruning end, 270 extra nodes, 0 pruned nodes, max_depth=9
# [15:56:57] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\tree\updater_prune.cc:101: tree pruning end, 270 extra nodes, 0 pruned nodes, max_depth=9
# [15:57:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\tree\updater_prune.cc:101: tree pruning end, 226 extra nodes, 0 pruned nodes, max_depth=9
# [15:57:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\tree\updater_prune.cc:101: tree pruning end, 226 extra nodes, 0 pruned nodes, max_depth=9
# [15:57:07] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\tree\updater_prune.cc:101: tree pruning end, 238 extra nodes, 0 pruned nodes, max_depth=9
# [15:57:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\tree\updater_prune.cc:101: tree pruning end, 238 extra nodes, 0 pruned nodes, max_depth=9
# [15:57:15] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\tree\updater_prune.cc:101: tree pruning end, 238 extra nodes, 0 pruned nodes, max_depth=9
# [15:57:18] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\tree\updater_prune.cc:101: tree pruning end, 238 extra nodes, 0 pruned nodes, max_depth=9
# [15:57:18] ======== Monitor: Learner ========
# [15:57:18] Configure: 0.000532s, 1 calls @ 532us
#
# [15:57:18] GetGradient: 0.090152s, 4 calls @ 90152us
#
# [15:57:18] PredictRaw: 0.346389s, 4 calls @ 346389us
#
# [15:57:18] UpdateOneIter: 30.0082s, 4 calls @ 30008172us
#
# [15:57:18] ======== Monitor: GBTree ========
# [15:57:18] BoostNewTrees: 28.7768s, 4 calls @ 28776819us
#
# [15:57:18] CommitModel: 1.3e-05s, 4 calls @ 13us
#
# [15:57:18] ======== Monitor: TreePruner ========
# [15:57:18] PrunerUpdate: 0.005903s, 8 calls @ 5903us
#
# model fitted
# 0.9928426201920242
# 0.992559369658673

# %%
import xgboost as xgb
import matplotlib.pyplot as plt
plt.style.use('seaborn')
fig, ax = plt.subplots(1,1,figsize=(10,15))
xgb.plot_importance(model, ax=ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
model
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-b0304bf42dd9> in <module>
# ----> 1 model.png
#
# AttributeError: 'XGBClassifier' object has no attribute 'png'

# %%
import pickle
pickle.dump(model, open(r"D:\Semester5Project\model.pickle", 'wb'))

# %%
model = pickle.load(open(r"D:\Semester5Project\model.pickle", 'rb'))

# %%
everything = pd.read_pickle("C:/Users/RAGHAV VERMA/Semester5Project/results.pickle")
everything
# Out:
#                           Training Accuracy  Testing Accuracy  Training DR  \
# Models
# Neural Network                    99.189806         99.153560     0.894059
# Naive Bayes Classifier            95.838907         95.804921     0.056281
# SVM                               98.149517         98.143893     0.859763
# Decision Tree                     99.274203         99.235912     0.870327
# XGBoost                           99.987934         99.646680     0.954730
# Random Forest Classifier          99.999372         99.473357     0.931072
# AdaBoost Classifier              100.000000         99.381081     0.924004
# Logistic Regression               98.745444         98.719359     0.930923
#
#                           Training FAR  Testing DR  Testing FAR  \
# Models
# Neural Network                0.008464    0.897857     0.008102
# Naive Bayes Classifier        0.041951    0.052629     0.041611
# SVM                           0.018561    0.861899     0.018505
# Decision Tree                 0.007641    0.874197     0.007258
# XGBoost                       0.003533    0.998144     0.000121
# Random Forest Classifier      0.005266    0.999855     0.000006
# AdaBoost Classifier           0.006189    1.000000     0.000000
# Logistic Regression           0.012806    0.932668     0.012546
#
#                           Precision for No Attack (Train)  \
# Models
# Neural Network                                   0.995390
# Naive Bayes Classifier                           0.958936
# SVM                                              0.993719
# Decision Tree                                    0.994339
# XGBoost                                          0.999916
# Random Forest Classifier                         0.999993
# AdaBoost Classifier                              1.000000
# Logistic Regression                              0.996937
#
#                           Recall for No Attack (Train)  \
# Models
# Neural Network                                0.996146
# Naive Bayes Classifier                        0.999302
# SVM                                           0.986897
# Decision Tree                                 0.998097
# XGBoost                                       0.999958
# Random Forest Classifier                      1.000000
# AdaBoost Classifier                           1.000000
# Logistic Regression                           0.989929
#
#                           F1 Score for No Attack (Train)  \
# Models
# Neural Network                                  0.995768
# Naive Bayes Classifier                          0.978703
# SVM                                             0.990296
# Decision Tree                                   0.996214
# XGBoost                                         0.999937
# Random Forest Classifier                        0.999997
# AdaBoost Classifier                             1.000000
# Logistic Regression                             0.993421
#
#                           Precision for Attack (Train)  \
# Models
# Neural Network                                0.913214
# Naive Bayes Classifier                        0.772932
# SVM                                           0.748189
# Decision Tree                                 0.954014
# XGBoost                                       0.999063
# Random Forest Classifier                      1.000000
# AdaBoost Classifier                           1.000000
# Logistic Regression                           0.807067
#
#                           Recall for Attack (Train)  \
# Models
# Neural Network                             0.897857
# Naive Bayes Classifier                     0.052629
# SVM                                        0.861899
# Decision Tree                              0.874197
# XGBoost                                    0.998144
# Random Forest Classifier                   0.999855
# AdaBoost Classifier                        1.000000
# Logistic Regression                        0.932668
#
#                           F1 Score for Attack (Train)  \
# Models
# Neural Network                               0.905470
# Naive Bayes Classifier                       0.098548
# SVM                                          0.801029
# Decision Tree                                0.912363
# XGBoost                                      0.998603
# Random Forest Classifier                     0.999927
# AdaBoost Classifier                          1.000000
# Logistic Regression                          0.865334
#
#                           Precision for No Attack (Test)  \
# Models
# Neural Network                                  0.995157
# Naive Bayes Classifier                          0.958582
# SVM                                             0.993541
# Decision Tree                                   0.994090
# XGBoost                                         0.997930
# Random Forest Classifier                        0.996849
# AdaBoost Classifier                             0.996525
# Logistic Regression                             0.996817
#
#                           Recall for No Attack (Test)  \
# Models
# Neural Network                               0.995995
# Naive Bayes Classifier                       0.999307
# SVM                                          0.987006
# Decision Tree                                0.997942
# XGBoost                                      0.998376
# Random Forest Classifier                     0.997646
# AdaBoost Classifier                          0.997005
# Logistic Regression                          0.989768
#
#                           F1 Score for No Attack (Test)  \
# Models
# Neural Network                                 0.995576
# Naive Bayes Classifier                         0.978521
# SVM                                            0.990263
# Decision Tree                                  0.996012
# XGBoost                                        0.998153
# Random Forest Classifier                       0.997247
# AdaBoost Classifier                            0.996765
# Logistic Regression                            0.993280
#
#                           Precision for Attack (Test)  \
# Models
# Neural Network                               0.910831
# Naive Bayes Classifier                       0.788021
# SVM                                          0.751691
# Decision Tree                                0.950866
# XGBoost                                      0.964162
# Random Forest Classifier                     0.947639
# AdaBoost Classifier                          0.933835
# Logistic Regression                          0.806302
#
#                           Recall for Attack (Test)  F1 Score for Attack (Test)
# Models
# Neural Network                            0.894059                    0.902367
# Naive Bayes Classifier                    0.056281                    0.105059
# SVM                                       0.859763                    0.802103
# Decision Tree                             0.870327                    0.908815
# XGBoost                                   0.954730                    0.959423
# Random Forest Classifier                  0.931072                    0.939282
# AdaBoost Classifier                       0.924004                    0.928893
# Logistic Regression                       0.930923                    0.864143

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import RFECV
from sklearn.model_selection import train_test_split
import xgboost as xgb

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop("Label",axis=1), df['Label'], test_size=0.2, random_state=0)

# %%
rfecv = RFECV(estimator=model, step=1, cv=10, scoring='accuracy')
rfecv = rfecv.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-e3674ab791b6> in <module>
#       1 rfecv = RFECV(estimator=DecisionTreeClassifier(random_state=42), step=1, cv=10, scoring='accuracy')
# ----> 2 rfecv = rfecv.fit(X_train, y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\_rfe.py in fit(self, X, y, groups)
#     506         """
#     507         tags = self._get_tags()
# --> 508         X, y = self._validate_data(
#     509             X, y, accept_sparse="csr", ensure_min_features=2,
#     510             force_all_finite=not tags.get('allow_nan', True),
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     793         raise ValueError("y cannot be None")
#     794
# --> 795     X = check_array(X, accept_sparse=accept_sparse,
#     796                     accept_large_sparse=accept_large_sparse,
#     797                     dtype=dtype, order=order, copy=copy,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     642
#     643         if force_all_finite:
# --> 644             _assert_all_finite(array,
#     645                                allow_nan=force_all_finite == 'allow-nan')
#     646
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      94                 not allow_nan and not np.isfinite(X).all()):
#      95             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 96             raise ValueError(
#      97                     msg_err.format
#      98                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
X_train_rfecv = rfecv.transform(X_train)
X_test_rfecv = rfecv.transform(X_test)

# %%
model = DecisionTreeClassifier(random_state=42).fit(X_train_rfecv,y_train)

# %%
logit.score(X_test_rfecv,y_test)
print(score)
